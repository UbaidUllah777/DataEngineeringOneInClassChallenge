# %% [markdown]
# ## STEP 1 — Hello, Data!
#
# In this step, I load the raw e-commerce sales CSV file using the `LoadSales` class.
# The first three records are displayed to confirm that the data was loaded successfully.

# %%
from Initialization import LoadSales
salesLoader= LoadSales().getSales()
# Out:
# Load Sales class created

# %% [markdown]
# ### Showing the top 3 Records

# %%
salesLoader.head(5)
# Out:
#    order_id        date customer_id product_id       product product_category  \
# 0  ON100762  2025-01-03      C11886      P2378      Lip Balm           Beauty
# 1  ON100888  2025-01-03      C10858      P1339     Air Fryer   Home & Kitchen
# 2  ON100375  2025-01-04      C12057      P8749  Coffee Maker   Home & Kitchen
# 3  ON100459  2025-01-04      C10823      P9067  Baseball Cap          Apparel
# 4  ON100833  2025-01-04      C10951      P1044        Cereal          Grocery
#
#    price  quantity coupon_code  discount_pct payment_method shipping_city  \
# 0  63.41         6   NO_COUPON           0.0    Credit Card        London
# 1  55.39         5    WELCOME5           5.0        Interac        Guelph
# 2  81.91         3   NO_COUPON           0.0    Credit Card      Hamilton
# 3  93.35         3   NO_COUPON           0.0     Debit Card       Vaughan
# 4  14.40         3   NO_COUPON           0.0    Credit Card   Scarborough
#
#   shipping_province  sales_amount
# ...
